# %% [markdown]
# <a href="https://colab.research.google.com/github/javiipzo/IronHack2/blob/main/Time_Series_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercise 1
#
#  - Import Barcelona_air_pollution data
#  - Find the most interessting series to predict
#  - Is it stationary? Is it seasonal?
#  - Predict and validate the pollution for the last 6 months
#  - Use wind_speed from weather data to improve your prediction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt

from prophet import Prophet
from sklearn import metrics

import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
air_pol = pd.read_csv('drive/MyDrive/Ironhack/Data/Barcelona_air_pollution.csv', sep = ';')
air_pol=air_pol.dropna()
air_pol['date_hour0'] = air_pol['date'] + ' ' + air_pol['hour'].astype(str)
air_pol['date_hour'] = pd.to_datetime(air_pol['date_hour0'], format = '%d/%m/%Y %H')
air_pol.drop(['date','hour','date_hour0'], axis = 1, inplace = True)
air_pol.tail(5)
# Out:
#            lon    lat      CO   NO   NO2     O3   SO2  PM2_5   PM10   NH3  \
# 17324  41.3888  2.159  216.96  0.0  0.07  40.05  0.05   2.71   5.42  0.37
# 17325  41.3888  2.159  216.96  0.0  0.07  38.98  0.05   3.10   6.23  0.40
# 17326  41.3888  2.159  213.62  0.0  0.07  41.13  0.09   4.61   9.95  0.41
# 17327  41.3888  2.159  210.29  0.0  0.06  45.06  0.11   5.32  12.26  0.36
# 17328  41.3888  2.159  213.62  0.0  0.06  48.64  0.09   4.33  10.00  0.30
#
#        aqi  year       city           date_hour
# 17324    1  2022  Barcelona 2022-12-31 20:00:00
# 17325    1  2022  Barcelona 2022-12-31 21:00:00
# 17326    1  2022  Barcelona 2022-12-31 22:00:00
# 17327    1  2022  Barcelona 2022-12-31 23:00:00
# 17328    1  2023  Barcelona 2023-01-01 00:00:00

# %%
weather = pd.read_csv('drive/MyDrive/Ironhack/Data/Barcelona_weather.csv', sep = ';')

weather['date'] = pd.to_datetime(weather['dt'],unit='s')
weather = weather[['date','temp','feels_like','pressure','humidity','wind_speed','rain_1h']]
weather['rain_1h'].fillna(0, inplace = True)
weather['year'] = weather['date'].dt.year
weather['month'] = weather['date'].dt.month
weather
# Out:
#                      date   temp  feels_like  pressure  humidity  wind_speed  \
# 0     2018-01-01 00:00:00  14.63       13.61      1018        56        9.30
# 1     2018-01-01 01:00:00  13.31       12.05      1019        52        6.70
# 2     2018-01-01 02:00:00  12.35       11.10      1020        56        6.70
# 3     2018-01-01 03:00:00  10.77        9.23      1021        51        7.72
# 4     2018-01-01 04:00:00  11.96       10.60      1022        53        8.75
# ...                   ...    ...         ...       ...       ...         ...
# 44504 2023-01-01 19:00:00  12.73       12.41      1025        90        1.54
# 44505 2023-01-01 20:00:00  12.28       11.91      1025        90        3.10
# 44506 2023-01-01 21:00:00  12.28       11.86      1024        88        4.10
# 44507 2023-01-01 22:00:00  11.96       11.48      1024        87        4.10
# 44508 2023-01-01 23:00:00  12.06       11.49      1024        83        5.10
#
#        rain_1h  year  month
# ...

# %%
air_pol = air_pol.merge(weather, left_on = 'date_hour', right_on = 'date', how = 'left')
air_pol.columns
air_pol.fillna(0,inplace=True)

# %%
plt.figure(figsize=(12, 7))
fig, ax = plt.subplots(figsize=(12, 7))
ax2 = ax.twinx()
# sns.lineplot(data = air_pol, x = 'date_hour', y = 'CO')
# ax.plt.plot(air_pol['date_hour'], air_pol['PM10'])
# ax.plt.plot(air_pol['date_hour'], air_pol['PM2_5'])
# ax2.plt.plot(air_pol['date_hour'], air_pol['CO'])
# plt.xticks(rotation=45);

# ax.plot(air_pol['date_hour'], air_pol['PM10'], color = 'red', label = 'PM10')
# ax.plot(air_pol['date_hour'], air_pol['PM2_5'], color = 'green', label = 'PM2.5')
ax.plot(air_pol['date_hour'], air_pol['CO'], color = 'blue', label = 'CO')
plt.legend()
plt.xticks(rotation=45);
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #SEGUN EL GRAFICO VEMOS QUE ES ESTACIONARIA

# %%
air_plot_train = air_pol[air_pol['date_hour']<='2022-10-31 23:00:0']
air_plot_test = air_pol[air_pol['date_hour']>'2022-10-31 23:00:0']

air_plot_train.drop(['lon','lat','city','aqi','year_x','year_y', 'date', 'rain_1h', 'month'], axis = 1, inplace = True)
air_plot_test.drop(['lon','lat','city','aqi','year_x','year_y', 'date', 'rain_1h', 'month'], axis = 1, inplace = True)

air_plot_train.columns = ['y', 'NO', 'NO2', 'O3', 'SO2', 'PM2_5', 'PM10', 'NH3','ds', 'temp', 'feels_like',
       'pressure', 'humidity', 'wind_speed']
air_plot_test.columns = ['y', 'NO', 'NO2', 'O3', 'SO2', 'PM2_5', 'PM10', 'NH3','ds', 'temp', 'feels_like',
       'pressure', 'humidity', 'wind_speed']

# air_plot_train['y'] = air_plot_train['y'].rolling(window=24).mean()
# air_plot_train['y'] = np.log(air_plot_train['y'])
air_plot_train
# Out:
#             y   NO   NO2     O3   SO2  PM2_5   PM10   NH3                  ds  \
# 0      243.66  0.0  0.07  41.84  0.07   5.12  11.97  0.41 2021-01-01 00:00:00
# 1      233.65  0.0  0.08  44.35  0.07   5.52  14.40  0.38 2021-01-01 01:00:00
# 2      226.97  0.0  0.08  46.49  0.06   5.83  16.02  0.34 2021-01-01 02:00:00
# 3      223.64  0.0  0.08  46.49  0.06   6.08  16.92  0.30 2021-01-01 03:00:00
# 4      220.30  0.0  0.09  46.49  0.06   6.44  17.89  0.26 2021-01-01 04:00:00
# ...       ...  ...   ...    ...   ...    ...    ...   ...                 ...
# 16105  223.64  0.0  0.06  14.31  0.02   0.65   0.99  0.26 2022-10-31 19:00:00
# 16106  216.96  0.0  0.07  12.87  0.03   0.76   1.12  0.25 2022-10-31 20:00:00
# 16107  208.62  0.0  0.08  12.70  0.03   0.81   1.12  0.22 2022-10-31 21:00:00
# 16108  205.28  0.0  0.08  13.41  0.03   0.85   1.14  0.20 2022-10-31 22:00:00
# 16109  203.61  0.0  0.09  13.95  0.03   0.93   1.23  0.18 2022-10-31 23:00:00
#
# ...

# %%
model = Prophet(seasonality_prior_scale=20, seasonality_mode='multiplicative', daily_seasonality=False)
model.add_regressor('NO2')
model.add_regressor('O3')
model.add_regressor('SO2')
model.add_regressor('temp')
model.add_regressor('wind_speed')
model.add_regressor('humidity')
model.add_regressor('NO')
model.fit(air_plot_train)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpde0k1cj5/n2gwm9mn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpde0k1cj5/b_k3wa2k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56526', 'data', 'file=/tmp/tmpde0k1cj5/n2gwm9mn.json', 'init=/tmp/tmpde0k1cj5/b_k3wa2k.json', 'output', 'file=/tmp/tmpde0k1cj5/prophet_modelrtbw7csu/prophet_model-20231025132008.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:20:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:20:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast_ts = model.predict(air_plot_test)
forecast_ts = forecast_ts.merge(air_plot_test, on = 'ds', how = 'inner')
forecast_ts = forecast_ts[['ds','y','yhat','yhat_lower','yhat_upper']]

# %%
print("MAE: ", metrics.mean_absolute_error(forecast_ts['y'], forecast_ts['yhat']).round(4))
print("MSE: ", metrics.mean_squared_error(forecast_ts['y'], forecast_ts['yhat']).round(4))
print("RMSE: ", np.sqrt(metrics.mean_squared_error(forecast_ts['y'], forecast_ts['yhat'])).round(4))
print("MAPE: ", metrics.mean_absolute_percentage_error(forecast_ts['y'], forecast_ts['yhat']).round(4))
# Out:
# MAE:  20.1234
# MSE:  754.5728
# RMSE:  27.4695
# MAPE:  0.089

# %%
model.plot(forecast_ts)
plt.show()

# %%
X = air_plot_train['y'].rolling(window=24).mean()
X.fillna(1,inplace=True)

# %%
from pandas import read_csv
from statsmodels.tsa.stattools import adfuller
result = adfuller(X)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('Critical Values:')
for key, value in result[4].items():
 print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -8.428506
# p-value: 0.000000
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567

# %%
# !pip install prophet

# %%
from prophet import Prophet

# %%
weather_2018 = weather[(weather['year'] == 2018) & (weather['month'] == 1)]

plt.figure(figsize=(8, 5))
sns.lineplot(data = weather_2018, x = 'date', y = 'feels_like')
plt.xticks(rotation=45);

# %%
# Calculate the moving average using a window of 7 (for example)
window = 24
weather['Moving_Avg'] = weather['feels_like'].rolling(window=window).mean()

# %%
weather_2018 = weather[(weather['year'] == 2018) & (weather['month'] == 1)]

plt.figure(figsize=(8, 5))
sns.lineplot(data = weather_2018, x = 'date', y = 'feels_like', c = 'blue', label = 'feels_like')
sns.lineplot(data = weather_2018, x = 'date', y = 'Moving_Avg', c = 'red', label = 'smooth')
plt.title('Daily average')
plt.legend()
plt.xticks(rotation=45);

# %%
def exponential_smoothing(series, alpha):

    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

def plot_exponential_smoothing(series, alphas):

    plt.figure(figsize=(10,6))
    for alpha in alphas:
        plt.plot(exponential_smoothing(series, alpha), label="Alpha {}".format(alpha))
    plt.plot(series.values, "c", label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Exponential Smoothing")
    plt.grid(True);

# %%
plot_exponential_smoothing(weather_2018.feels_like, [0.05, 0.3])

# %% [markdown]
# #INTENTARE TAMBIEN PREDECIR EL CO (estacionario)

# %%
co=air_pol[["CO","date_hour"]]

# %%
co
# Out:
#            CO           date_hour
# 0      243.66 2021-01-01 00:00:00
# 1      233.65 2021-01-01 01:00:00
# 2      226.97 2021-01-01 02:00:00
# 3      223.64 2021-01-01 03:00:00
# 4      220.30 2021-01-01 04:00:00
# ...       ...                 ...
# 17521  216.96 2022-12-31 20:00:00
# 17522  216.96 2022-12-31 21:00:00
# 17523  213.62 2022-12-31 22:00:00
# 17524  210.29 2022-12-31 23:00:00
# 17525  213.62 2023-01-01 00:00:00
#
# [17526 rows x 2 columns]

# %%
co = co.rename(index=str, columns={"CO": "y", "date_hour": "ds"})

# %%
co_train = co[co['ds']< '2022-07-01']
co_test = co[co['ds']>= '2022-07-01']

# %%
model = Prophet()
model.fit(co_train)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpde0k1cj5/vltz5fg8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpde0k1cj5/whwb50bj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34570', 'data', 'file=/tmp/tmpde0k1cj5/vltz5fg8.json', 'init=/tmp/tmpde0k1cj5/whwb50bj.json', 'output', 'file=/tmp/tmpde0k1cj5/prophet_modelekiz2tw8/prophet_model-20231025132815.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 13:28:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 13:28:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
forecast_fl_ts = model.predict(co_test)

# %%
forecast_fl_ts = forecast_fl_ts[['ds','yhat','yhat_lower','yhat_upper']]
forecast_fl_ts.head(3)
# Out:
#                    ds        yhat  yhat_lower  yhat_upper
# 0 2022-07-01 00:00:00  198.865636  173.724119  223.913703
# 1 2022-07-01 01:00:00  199.125457  173.358556  223.907252
# 2 2022-07-01 02:00:00  199.572431  175.328321  221.797348

# %%
model.plot(forecast_fl_ts)
plt.show()
